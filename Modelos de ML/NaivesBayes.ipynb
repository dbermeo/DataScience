# %%
import pandas as pd
import numpy as np
from sklearn.naive_bayes import BernoulliNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
df=pd.read_csv("D:/Windows/User/Documentos/ciencia de datos/Recursos/2008.csv")
df=df.sample(frac=1)
df=df.head(500000)

# %%
df=df.dropna(subset=['ArrDelay'])

# %%
Y=df['ArrDelay']>0

# %%
df['Month']=df['Month'].apply(str)
df['DayofMonth']=df['DayofMonth'].apply(str)
df['DayOfWeek']=df['DayOfWeek'].apply(str)
df['TailNum']=df['TailNum'].apply(str)

X=pd.get_dummies(data=df[['Month','DayofMonth','DayOfWeek','Origin','Dest','UniqueCarrier']])

# %%
X.head()
# Out:
#          Month_1  Month_10  Month_11  Month_12  Month_2  Month_3  Month_4  \
# 3695531        0         0         0         0        0        0        0
# 6709159        0         0         0         1        0        0        0
# 4575112        0         0         0         0        0        0        0
# 5226029        0         0         0         0        0        0        0
# 3895583        0         0         0         0        0        0        0
#
#          Month_5  Month_6  Month_7  ...  UniqueCarrier_HA  UniqueCarrier_MQ  \
# 3695531        0        0        1  ...                 0                 0
# 6709159        0        0        0  ...                 0                 0
# 4575112        0        0        0  ...                 0                 0
# 5226029        0        0        0  ...                 0                 0
# 3895583        0        0        1  ...                 0                 0
#
#          UniqueCarrier_NW  UniqueCarrier_OH  UniqueCarrier_OO  \
# 3695531                 0                 0                 0
# 6709159                 0                 0                 0
# 4575112                 0                 0                 0
# 5226029                 1                 0                 0
# 3895583                 0                 0                 0
#
#          UniqueCarrier_UA  UniqueCarrier_US  UniqueCarrier_WN  \
# 3695531                 0                 0                 1
# 6709159                 0                 1                 0
# 4575112                 0                 0                 0
# 5226029                 0                 0                 0
# 3895583                 0                 1                 0
#
#          UniqueCarrier_XE  UniqueCarrier_YV
# 3695531                 0                 0
# 6709159                 0                 0
# 4575112                 0                 0
# 5226029                 0                 0
# 3895583                 0                 0
#
# [5 rows x 672 columns]

# %%
clf=BernoulliNB()
clf.fit(X,Y)
Y_pred=clf.predict(X)

# %%
np.mean(Y==Y_pred)
# Out:
# 0.5925239071806395
