# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("D:/Windows/User/Documentos/ciencia de datos/Recursos/2008.csv",nrows=1000000)
df
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0       2008      1           3          4   2003.0        1955   2211.0
# 1       2008      1           3          4    754.0         735   1002.0
# 2       2008      1           3          4    628.0         620    804.0
# 3       2008      1           3          4    926.0         930   1054.0
# 4       2008      1           3          4   1829.0        1755   1959.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999995  2008      2          12          2   1648.0        1655   1959.0
# 999996  2008      2          13          3   1647.0        1655   2013.0
# 999997  2008      2          14          4   1653.0        1655   2000.0
# 999998  2008      2          15          5   1650.0        1655   1951.0
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0             2225            WN        335  ...    4.0      8.0          0
# 1             1000            WN       3231  ...    5.0     10.0          0
# 2              750            WN        448  ...    3.0     17.0          0
# 3             1100            WN       1746  ...    3.0      7.0          0
# 4             1925            WN       3920  ...    3.0     10.0          0
# ...            ...           ...        ...  ...    ...      ...        ...
# 999995        2005            MQ       4695  ...    4.0      8.0          0
# 999996        2005            MQ       4695  ...    6.0     16.0          0
# 999997        2005            MQ       4695  ...    3.0     10.0          0
# 999998        2005            MQ       4695  ...    4.0     10.0          0
# 999999        2005            MQ       4695  ...    NaN      NaN          1
#
#         CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0                    NaN         0           NaN          NaN      NaN
# 1                    NaN         0           NaN          NaN      NaN
# 2                    NaN         0           NaN          NaN      NaN
# 3                    NaN         0           NaN          NaN      NaN
# 4                    NaN         0           2.0          0.0      0.0
# ...                  ...       ...           ...          ...      ...
# 999995               NaN         0           NaN          NaN      NaN
# 999996               NaN         0           NaN          NaN      NaN
# 999997               NaN         0           NaN          NaN      NaN
# 999998               NaN         0           NaN          NaN      NaN
# 999999                 B         0           NaN          NaN      NaN
#
#         SecurityDelay  LateAircraftDelay
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 0.0               32.0
# ...               ...                ...
# 999995            NaN                NaN
# 999996            NaN                NaN
# 999997            NaN                NaN
# 999998            NaN                NaN
# 999999            NaN                NaN
#
# [1000000 rows x 29 columns]

# %%
data = np.unique(df.Cancelled, return_counts=True)
data
# Out:
# (array([0, 1], dtype=int64), array([967867,  32133], dtype=int64))

# %%
plt.pie(x=data[1],labels = data[0],colors=['Red','blue'],radius=2)
plt.show()

# %%
df=df.sample(frac=1).head(100)

# %%
plt.scatter(x=df.DayofMonth,y=df.ArrDelay,s=df.Distance)

# %%
plt.scatter(x=df.DayofMonth,y=df.ArrDelay,s=df.Distance,alpha=.3,c=df.DayOfWeek.isin([6,7]))
plt.title('Retrasos en EEUU')
plt.xlabel("Dia del mes")
plt.ylabel("Retrasos de llegada")
plt.text(x=24,y=155,s="Mi vuelo")
# Out:
# Text(24, 155, 'Mi vuelo')

# %%
df1=pd.read_csv("D:/Windows/User/Documentos/ciencia de datos/Recursos/2008.csv",nrows=1000000)
df1
# Out:
#         Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0       2008      1           3          4   2003.0        1955   2211.0
# 1       2008      1           3          4    754.0         735   1002.0
# 2       2008      1           3          4    628.0         620    804.0
# 3       2008      1           3          4    926.0         930   1054.0
# 4       2008      1           3          4   1829.0        1755   1959.0
# ...      ...    ...         ...        ...      ...         ...      ...
# 999995  2008      2          12          2   1648.0        1655   1959.0
# 999996  2008      2          13          3   1647.0        1655   2013.0
# 999997  2008      2          14          4   1653.0        1655   2000.0
# 999998  2008      2          15          5   1650.0        1655   1951.0
# 999999  2008      2          17          7      NaN        1655      NaN
#
#         CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0             2225            WN        335  ...    4.0      8.0          0
# 1             1000            WN       3231  ...    5.0     10.0          0
# 2              750            WN        448  ...    3.0     17.0          0
# 3             1100            WN       1746  ...    3.0      7.0          0
# 4             1925            WN       3920  ...    3.0     10.0          0
# ...            ...           ...        ...  ...    ...      ...        ...
# 999995        2005            MQ       4695  ...    4.0      8.0          0
# 999996        2005            MQ       4695  ...    6.0     16.0          0
# 999997        2005            MQ       4695  ...    3.0     10.0          0
# 999998        2005            MQ       4695  ...    4.0     10.0          0
# 999999        2005            MQ       4695  ...    NaN      NaN          1
#
#         CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0                    NaN         0           NaN          NaN      NaN
# 1                    NaN         0           NaN          NaN      NaN
# 2                    NaN         0           NaN          NaN      NaN
# 3                    NaN         0           NaN          NaN      NaN
# 4                    NaN         0           2.0          0.0      0.0
# ...                  ...       ...           ...          ...      ...
# 999995               NaN         0           NaN          NaN      NaN
# 999996               NaN         0           NaN          NaN      NaN
# 999997               NaN         0           NaN          NaN      NaN
# 999998               NaN         0           NaN          NaN      NaN
# 999999                 B         0           NaN          NaN      NaN
#
#         SecurityDelay  LateAircraftDelay
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 0.0               32.0
# ...               ...                ...
# 999995            NaN                NaN
# 999996            NaN                NaN
# 999997            NaN                NaN
# 999998            NaN                NaN
# 999999            NaN                NaN
#
# [1000000 rows x 29 columns]

# %%
data=np.unique(df1.DayOfWeek,return_counts=True)
labs=['lunes','Martes','Miercoles','Juevez','Viernes','Sabado','Domingo']

# %%
data
# Out:
# (array([1, 2, 3, 4, 5, 6, 7], dtype=int64),
#  array([137229, 152498, 155928, 159416, 153724, 112352, 128853],
#        dtype=int64))

# %%
plt.pie(x=data1[1],labels = labs,colors=sns.color_palette("hls",7),explode=(0,0,0,0,0,0,0.1),radius=2,
       autopct="%1.1f%%")
plt.legend(loc="upper right",labels=labs)
plt.show()

# %%
plt=sns.barplot(x=labs,y=data[1])
plt.set(xlabel='Dias d el semana')
# Out:
# [Text(0.5, 0, 'Dias d el semana')]

# %%
df=pd.read_csv("D:/Windows/User/Documentos/ciencia de datos/Recursos/2008.csv")
df2=df[df['Origin'].isin(['ATL','HOU','IND'])]
df=df.head(500000)

# %%
import datetime
import time

# %%
times=[]
for i in np.arange(len(df)):
    times.append(datetime.datetime(year=2008,month=df.loc[i,"Month"],day=df.loc[i,"DayofMonth"]))

# %%
times[50000]
# Out:
# datetime.datetime(2008, 1, 18, 0, 0)

# %%
df["Time"]=times

# %%
data=df.groupby(by=['Time'],as_index=False)["DepDelay","ArrDelay"].mean()
data.head()
# Out:
# <ipython-input-266-9fec0aa968ed>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data=df.groupby(by=['Time'],as_index=False)["DepDelay","ArrDelay"].mean()
#         Time   DepDelay   ArrDelay
# 0 2008-01-01  20.545599  20.999240
# 1 2008-01-02  23.324222  22.131194
# 2 2008-01-03  16.697759  14.479569
# 3 2008-01-04  14.058087  11.851733
# 4 2008-01-05  18.381555  17.138031

# %%
sns.lineplot(data["Time"],data['DepDelay'])
# Out:
# C:\Users\Dann\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Time', ylabel='DepDelay'>

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>

# %%
times=[]
for i in df2.index:
    times.append(datetime.datetime(year=2008,month=df2.loc[i,'Month'],day=df2.loc[i,"DayofMonth"]))
    
df2['TIME']=times

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x=df2["TIME"],y='ArrDelay',hue="Origin",data=df2)
# Out:
# <AxesSubplot:xlabel='TIME', ylabel='ArrDelay'>

# %%
df=pd.read_csv("D:/Windows/User/Documentos/ciencia de datos/Recursos/2008.csv")

# %%
df.dropna(inplace=True,subset=['ArrDelay','DepDelay','Distance'])

# %%
sns.displot(df.Distance,kde=False,bins=100)

# %%
#sns.kdeplot(df.ArrDelay)
#sns.kdeplot(df.DepDelay)
#plt.xlim([-300,300])

# %%
sns.boxplot(x='DepDelay',y="Origin",data=df2)
plt.xlim([-20,150])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-282-59f03bc3424c> in <module>
#       1 sns.boxplot(x='DepDelay',y="Origin",data=df2)
# ----> 2 plt.xlim([-20,150])
#
# AttributeError: 'AxesSubplot' object has no attribute 'xlim'

# %%
df=pd.read_csv("D:/Windows/User/Documentos/ciencia de datos/Recursos/2008.csv")

# %%
df.dropna(inplace=True,subset=['ArrDelay','DepDelay','Distance','AirTime'])
sns.set(rc={'figure.figsize':(15,10)})

# %%
df2=df[df["Origin"].isin(['ATL','HOU','IND'])].sample(frac=1).head(1000)
sns.jointplot(df2['DepDelay'],df2['ArrDelay'])
# Out:
# C:\Users\Dann\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df3=df2[np.abs(df2['DepDelay'])<40]
df3=df3[np.abs(df3['ArrDelay'])<40]

# %%
sns.jointplot(df3.DepDelay,df3.ArrDelay,kind='hex')
# Out:
# C:\Users\Dann\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df3.DepDelay,df3.ArrDelay,kind='kde')
# Out:
# C:\Users\Dann\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
gb_df=pd.DataFrame(df2.groupby(["Origin","Month"],as_index=False)['DepDelay'].mean())

# %%
gb_df.head()
# Out:
#   Origin  Month   DepDelay
# 0    ATL      1   5.413793
# 1    ATL      2  20.068966
# 2    ATL      3  11.589041
# 3    ATL      4  19.279412
# 4    ATL      5   7.637681

# %%
data=gb_df.pivot('Month','Origin','DepDelay')
data
# Out:
# Origin        ATL        HOU        IND
# Month
# 1        5.413793   5.000000  -4.166667
# 2       20.068966  32.000000  -4.000000
# 3       11.589041  16.777778  43.333333
# 4       19.279412  16.416667   6.571429
# 5        7.637681   7.800000  -0.545455
# 6       14.493151   4.800000  25.600000
# 7       12.880597  10.166667  19.222222
# 8       10.075949   0.818182  26.400000
# 9        5.512821  -2.222222  -5.428571
# 10       9.147541   2.500000  -0.500000
# 11      10.287671  10.272727   2.000000
# 12      12.413793  68.000000  15.875000

# %%
sns.set(rc={'figure.figsize':(15,8)})
sns.heatmap(data=data,annot=True,linewidths=.5)
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='Month'>

# %%
np.
