# %%
import pandas as pd
import urllib3 as url3

# %%
def dowloadfromsisa(url):
    http = url3.PoolManager()
    datos = (http.request('GET', url).data).decode('utf-8').strip().split("\r")
    columnas = datos[0].split(",")
    for i in range(len(columnas)):
        columnas[i]= columnas[i].replace('"','')
    diccionario={columna:[] for columna in columnas}
    for linea in range(1,len(datos)):
        for i in range(0,len(columnas)):
                         [diccionario[columnas[i]].append(datos[linea].strip().split(",")[i].replace('"',''))]
    df=pd.DataFrame(diccionario).list_rowss(table,max_results=100000).to_dataframe()
    return df
    df['positivos']=df['positivos'].replace("","0")
    #df.to_excel("covid19Ejem.xlsx")
    #df.to_json("covid19Ejem.json")
    return df

# %%
df_covid = dowloadfromsisa('https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Determinaciones.csv')
df_covid.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-4c93418001fa> in <module>()
# ----> 1 df_covid = dowloadfromsisa('https://sisa.msal.gov.ar/datos/descargas/covid-19/files/Covid19Determinaciones.csv')
#       2 df_covid.head()
#
# <ipython-input-6-a70fe19afcae> in dowloadfromsisa(url)
#       9         for i in range(0,len(columnas)):
#      10                          [diccionario[columnas[i]].append(datos[linea].strip().split(",")[i].replace('"',''))]
# ---> 11     df=pd.DataFrame(diccionario).list_rowss(table,max_results=100000).to_dataframe()
#      12     return df
# ...
